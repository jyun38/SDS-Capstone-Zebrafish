# %% [markdown]
# # PSI Files

# %% [markdown]
# ### Read in PSI Files

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import statsmodels.api as sm

import plotly
plotly.tools.set_credentials_file(username='jyun38', api_key='AGILDzSjoJM0E9rewLbK')
plotly.tools.set_config_file(sharing='public', world_readable=True)
import plotly.graph_objs as go
from plotly.graph_objs import Scatter, Figure, Layout
# Out:
# //anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
wt = pd.read_csv('../Output-WT-01-17-10-21/wildtype_101_AT.psi', delimiter=' ', header = 19, names = ['x', 'y', 'z', 'a', 'r', 't'], index_col = 0)
print(wt.head())
print(np.shape(wt))
# Out:
#            x         y          z          a         r          t
# 1 -57.142525  1.043483 -12.023183  42.758357  3.100708  25.529734
# 2 -57.287431  1.160608 -11.717759  42.983255  3.095804  25.355698
# 3 -55.520142  2.572127  -8.403139  43.301426  3.026213  22.342203
# 4 -55.512742  2.632191  -8.255026  43.363142  3.022943  22.236719
# 5 -55.353034  2.635195  -8.264224  43.254083  3.022529  22.185093
# (717459, 6)

# %%
yot = pd.read_csv('../Output-yot-01-17-10-24/you-too_01_AT.psi', delimiter=' ', header = 19, names = ['x', 'y', 'z', 'a', 'r', 't'], index_col = 0)
print(yot.head())
print(np.shape(yot))
# Out:
#            x          y          z          a         r          t
# 1  -7.167169 -15.922585  15.323356   9.315287 -0.826894  21.638900
# 2  -6.687169 -15.462393  15.072909   8.659478 -0.817742  21.192862
# 3  -6.527169 -15.462393  15.072909   8.455678 -0.816820  21.211209
# 4  16.192831  -2.445724  -1.356699 -15.570151 -2.490046   4.033074
# 5  -6.527169 -15.296493  15.201662   8.477253 -0.807122  21.177483
# (21478, 6)

# %%
yot_df = yot[['a', 'r', 't']]

# %%
yot_data = [
    go.Surface(
        z = yot_df.as_matrix())
]
myLayout = go.Layout(
    title= 'yot', 
    autosize= False,
    width = 500, 
    height = 500, 
    margin=dict(
        l=65,
        r=50,
        b=65,
        t=90
    )
)
myFig = go.Figure(data=yot_data, layout=myLayout)
plotly.plotly.iplot(myFig, filename = 'file1')
# Out:
# ---------------------------------------------------------------------------
# PlotlyDictValueError                      Traceback (most recent call last)
# <ipython-input-15-b4101d2c37db> in <module>()
#      15     )
#      16 )
# ---> 17 myFig = go.Figure(data=yot_df, layout=myLayout)
#      18 plotly.plotly.iplot(myFig, filename = 'file1')
#
# //anaconda/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __init__(self, *args, **kwargs)
#    1161
#    1162     def __init__(self, *args, **kwargs):
# -> 1163         super(Figure, self).__init__(*args, **kwargs)
#    1164         if 'data' not in self:
#    1165             self.data = Data(_parent=self, _parent_key='data')
#
# //anaconda/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __init__(self, *args, **kwargs)
#     375         d = {key: val for key, val in dict(*args, **kwargs).items()}
#     376         for key, val in d.items():
# --> 377             self.__setitem__(key, val, _raise=_raise)
# ...

# %%
yot2 = pd.read_csv('../Output-yot-01-17-10-24/you-too_02_ZRF1.psi', delimiter=' ', header = 19, names = ['x', 'y', 'z', 'a', 'r', 't'], index_col = 0)
print(yot2.head())
print(np.shape(yot2))
# Out:
#            x         y          z          a         r          t
# 1 -49.345605  5.069224 -21.284725  31.722977  2.978214  31.165922
# 2 -49.665605  5.069224 -21.284725  31.907067  2.978728  31.263447
# 3 -49.185605  4.986084 -21.148022  31.680764  2.980025  30.995256
# 4 -49.345605  4.986084 -21.148022  31.772995  2.980281  31.044044
# 5 -49.505605  4.986084 -21.148022  31.865167  2.980536  31.092893
# (199505, 6)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')
ax.scatter(
    np.array(yot2.a),
    np.array(yot2.r),
    np.array(yot2.t),
    label='curve in (x,y)',
    alpha=0.1, s=0.1, c='blue')

# %%
wt2 = pd.read_csv('../Output-WT-01-17-10-21/wildtype_107_AT.psi', delimiter=' ', header = 19, names = ['x', 'y', 'z', 'a', 'r', 't'], index_col = 0)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')
ax.scatter(np.array(wt2.a), 
           np.array(wt2.r), 
           np.array(wt2.t), 
           label='curve in (x,y)', 
           alpha=0.1, s=0.1, c='red')

# %% [markdown]
# ### Comparing Two Samples

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')
ax.scatter(
    np.array(yot.a),
    np.array(yot.r),
    np.array(yot.t),
    label='curve in (x,y)',
    alpha=0.1, s=0.1, c='blue')

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')
ax.scatter(np.array(wt.a), 
           np.array(wt.r), 
           np.array(wt.t), 
           label='curve in (x,y)', 
           alpha=0.1, s=0.1, c='red')

# %%
yot2 = pd.read_csv('../Output-yot-01-17-10-24/you-too_02_AT.psi', delimiter=' ', header = 19, names = ['x', 'y', 'z', 'a', 'r', 't'], index_col = 0)
print(yot2.head())
print(np.shape(yot2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-82888cb6e5b7> in <module>()
# ----> 1 yot2 = pd.read_csv('../Output-yot-01-17-10-24/you-too_02_AT.psi', delimiter=' ', header = 19, names = ['x', 'y', 'z', 'a', 'r', 't'], index_col = 0)
#       2 print(yot2.head())
#       3 print(np.shape(yot2))
#
# ...

# %%
# the histogram of the data
plt.figure(figsize=(15, 10)) 
plt.subplot(2, 1, 1)
plt.hist(yot.a, 50, facecolor='b', alpha=0.5, normed=True)
plt.xlabel('α', fontsize = 16)
plt.title('Histogram of α for a YOT sample', fontsize = 18)

plt.grid(True)


plt.subplot(2, 1, 2)
plt.hist(wt.a, 50, facecolor='r', alpha=0.5, normed=True)
plt.xlabel('α', fontsize = 16)
plt.title('Histogram of α for a WT sample', fontsize = 18)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# the histogram of the data
plt.figure(figsize=(15, 10)) 
plt.subplot(2, 1, 1)
plt.hist(yot.r, 50, facecolor='b', alpha=0.5, normed=True)
plt.xlabel('R', fontsize=16)
plt.title('Histogram of R for a YOT sample', fontsize=18)
plt.grid(True)


plt.subplot(2, 1, 2)
plt.hist(wt.r, 50, facecolor='r', alpha=0.5, normed=True)
plt.xlabel('R', fontsize=16)
plt.title('Histogram of R for a WT sample', fontsize=18)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# the histogram of the data
plt.figure(figsize=(15, 10)) 
plt.subplot(2, 1, 1)
plt.hist(yot.t, 50, facecolor='b', alpha=0.5, normed=True)
plt.xlabel('θ', fontsize=16)
plt.title('Histogram of θ for a YOT sample', fontsize=18)
plt.grid(True)


plt.subplot(2, 1, 2)
plt.hist(wt.t, 50, facecolor='r', alpha=0.5, normed=True)
plt.xlabel('θ', fontsize=16)
plt.title('Histogram of θ for a WT sample', fontsize=18)
plt.grid(True)
plt.tight_layout()
plt.show()
